# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: Alberto Carrera
#
# Nome: Gabriel Barbosa
#
# Nome: Rodrigo Gomes

# %% [markdown]
# Atenção: Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# Carregando algumas bibliotecas:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# /Users/gabrielbarbosa/Desktop/Projeto1_CDados

# %% [markdown]
# Carregando a base de dados com os tweets classificados como relevantes e não relevantes:

# %%
filename = 'tesla.xlsx'

# %%
train = pd.read_excel(filename)
train.head(5)
# Out:
#                                          Treinamento  Classificação
# 0  @gnavarrocbz tesla é totalmente fora de cogita...              1
# 1  em 2025 a vw quer disponibilizar em algumas ci...              2
# 2              @repl1cunt diga isso ao dono do tesla              0
# 3  @al43610394 @felipeneto ah é? elon musk é o qu...              1
# 4                              @shipheroshe a tesla.              1

# %%
test = pd.read_excel(filename, sheet_name = 'Teste')
test.head(5)
# Out:
#                                                Teste  Classificação  \
# 0  @h3nrys2 quem curtir aqui vai me dar um porsch...              1
# 1  terminei o bendito resumo do tesla e to me sen...              1
# 2              @mattayahumateus aluga um tesla matta              1
# 3  100% elétrico: como foi a experiência de dirig...              3
# 4  gente off aqui eu tentei ouvir tesla na viagem...              3
#
#    Classificador
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
test.value_counts()
# Out:
# Series([], dtype: int64)

# %%
train = pd.read_excel(filename, sheet_name = 'Treinamento')
train.head(5)
# Out:
#                                          Treinamento  Classificação
# 0  @gnavarrocbz tesla é totalmente fora de cogita...              1
# 1  em 2025 a vw quer disponibilizar em algumas ci...              2
# 2              @repl1cunt diga isso ao dono do tesla              0
# 3  @al43610394 @felipeneto ah é? elon musk é o qu...              1
# 4                              @shipheroshe a tesla.              1

# %% [markdown]
# ___
# ## Classificador automático de sentimento

# %% [markdown]
# Faça aqui uma descrição do seu produto e o que considerou como relevante ou não relevante na classificação dos tweets.
#
# Classificados como 0:
# - Tweets que falam sobre Nikola Tesla
# - Tweets que só marcam pessoas e não falam sobre o produto
#
#
# Classificados como 1:
# - Fala sobre o produto
#
#
# Classificados como 2:
# - Falam diretamente sobre o produto, criticando ou elogiando
#
#
# Classificados como 3:
# - Falam diretamente sobre o produto, criticando ou elogiando
# - Além de se aprofundar no assunto, ou falando sobre ações ou sobre planos futuros, etc.

# %% [markdown]
# ___
# ### Montando um Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %%
import re 


def cleanup(text):
    """
        Função de limpeza muito simples que troca alguns sinais básicos por espaços
    """
    #import string
    punctuation = '[!-.:?;]' # Note que os sinais [] são delimitadores de um conjunto.
    #biblio "emoji", get_emoji_regexp
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, '', text)
    
    return text_subbed
def arroba(text):
    punctuation = r'@\w+'
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, '', text)
    return text_subbed

def sacaarrobas(x):
    arrobas=[]
    palavras=x.split()
    for coisas in palavras:
        if coisas[0]=='@':
            arrobas.append(coisas)
    for palavra in arrobas:
        palavras.remove(palavra)
    sobra=' '.join(palavras)
    return sobra

# %%
train.Treinamento= train.Treinamento.apply(cleanup)
train.Treinamento=   train.Treinamento.apply(arroba)
treino.to_frame()
# Out:
#                                            Treinamento
# 0                tesla é totalmente fora de cogitação?
# 1    em 2025 a vw quer disponibilizar em algumas ci...
# 2                           diga isso ao dono do tesla
# 3    ah é? elon musk é o que? como ele montou a tes...
# 4                                             a tesla.
# ..                                                 ...
# 645  hawking e schrödinger. as linhas de pensamento...
# 646  eh muito louco isso né. vi um vídeo do o tesla...
# 647  magnata chinês que comprou volvo da ford plane...
# 648  eletricidade foi o mais marcou a carreira de t...
# 649          do do do do do :) https://t.co/shryb3pxmn
#
# [650 rows x 1 columns]

# %%
cat0=train.loc[train['Classificação']==0,:]
categoria0=cat0.Treinamento.apply(cleanup).to_frame()
tweets0=''
for tweet in categoria0.Treinamento:
    tweets0 += ' '
    tweets0+= str(tweet)
tweets0
# Out:
# ' diga isso ao dono do tesla que maldade poderia de atochada não basta ter uma pista maior é preciso ter voos regulares eu tô passando mal vei como pode ser tão lerdo foi sorte nikola tesla era genial eu queria ter conhecido pessoalmente pergunta adm qual sua opinião sobre nikolas teslase você tiver uma e claro a tesla já tem o destino dela traçado com o aladin mil desculpas bem que eu queria que ela largasse ele e ficasse com o cantor teen k “bro” crl esse tesla virando charizard boa madu dps dessa tu quer oq porra um prêmio nobel por acaso ow nikola tesla da geração z lineu considerado pai da taxonomia estudou o sistema de classificação dos guaranis e a partir dele sem dar os devidos créditos criou a taxonomia em latim a ciência é marcada por apagamentos e violências simbólicas busquem saber a história de tesla e da rosalind franklin jungkook foi mencionado ao lado de príncipe harry e meghan markle o ceo da tesla e spacex elon musk e o fundador da amazon jeff bezos 🖇 https//tco/j5o1vccq88 jungkook 정국 ジョングク via jungkookpress lutz is a yutz esse é possivelmente o melhor resumo de nikola tesla que eu já li o local teria sido recentemente comprado por us 125 milhões pela apple que o teria alugado nos últimos cinco anos de acordo com o az big media https//tco/zll1uuhbqd noa newsonapple apple iphone ipad applecar icar car tesla appleev se isso for verdade cm a poha de dinheiro q o bolsonaro tem se compra a poha de um tesla pros seus pais a maioria das pessoas está tão absorta na contemplação do mundo exterior que está totalmente alheia ao que está acontecendo em si nikola tesla bem que você podia fazer algo usando a turbina de tesla que se utiliza do efeito de viscosidade para funcionar ser o nikola tesla parece bom quem foi que colocou elon musk e tesla no nct life nem gteult pensaria nisso bravo gosto mt de jordan mas tem tanto tenis que da de 10 a zero só a linha completa da tesla skate ja pisa zerei nikola tesla português/inglês em todas as plataformas nada p/ fazer 🙁 queria tanto virar professora de artes serasse o tesla me contrata
# %%
tudo=tweets0+' '+tweets1+' '+tweets2+' '+tweets3

portugues=tudo.split()
series_portugues=pd.Series(portugues)
series_portugues
# Out:
# 0                         diga
# 1                         isso
# 2                           ao
# 3                         dono
# 4                           do
#                  ...
# 10618                    tesla
# 10619                       me
# 10620                       da
# 10621                       um
# 10622    https//tco/hx8zjudtwy
# Length: 10623, dtype: object

# %%
#Mostra quanto uma palavra apareceu em cada classificacao
todotweet0=tweets0.split()
series_todotweet0=pd.Series(todotweet0)
tabela_tweets0=series_todotweet0.value_counts(True)

todotweet1=tweets1.split()
series_todotweet1=pd.Series(todotweet1)
tabela_tweets1=series_todotweet1.value_counts(True)

todotweet2=tweets2.split()
series_todotweet2=pd.Series(todotweet2)
tabela_tweets2=series_todotweet2.value_counts(True)

todotweet3=tweets3.split()
series_todotweet3=pd.Series(todotweet3)
tabela_tweets3=series_todotweet3.value_counts(True)

# %%
#Acha a probabilidade de 0, 1, 2 e 3
prob0 = len(series_todotweet0)/len(series_portugues)
prob1 = len(series_todotweet1)/len(series_portugues)
prob2 = len(series_todotweet2)/len(series_portugues)
prob3 = len(series_todotweet3)/len(series_portugues)
soma = prob0+prob1+prob2+prob3
soma
# Out:
# 0.9999999999999999

# %% [markdown]
# ___
# ### Verificando a performance do Classificador
#
# Agora você deve testar o seu classificador com a base de Testes.

# %%
#dando cleanup na tabela de testes
test.Teste = test.Teste.apply(cleanup)
test.Teste = test.Teste.apply(arroba)

# %%
#rodando o classificador com os tweets teste
def classificador(tweet):
    split_tweet = tweet.split()
    lista_probcats=[]
    #Comecando o calculo da prob com 1 para nao zerar o resutado
    probcat0=1
    probcat1=1
    probcat2=1
    probcat3=1
    
    #Calculando as probabilidades do tweets estar em cada uma das categorias
    for palavra in split_tweet:
        if palavra in portugues:
            if palavra in tabela_tweets0:
                c0= tabela_tweets0[palavra]
            else:
                c0=1 
            probcat0 = probcat0*c0
            if palavra in tabela_tweets1:    
                c1= tabela_tweets1[palavra]
            else:
                c1=1
            probcat1 = probcat1*c1
            if palavra in tabela_tweets2:
                c2= tabela_tweets2[palavra]
            else:
                c2 = 1
            probcat2 = probcat2*c2
            if palavra in tabela_tweets3:
                c3= tabela_tweets3[palavra]
            else:
                c3 = 1
            probcat3 = probcat3*c3
        else:
            probcat0=probcat0*1
            probcat1=probcat1*1
            probcat2=probcat2*1
            probcat3=probcat3*1
    
        
    #Comparando as probabilidades
    lista_probcats.append(probcat0)
    lista_probcats.append(probcat1)
    lista_probcats.append(probcat2)
    lista_probcats.append(probcat3)
    
    categoria_pertencente=max(lista_probcats)
    if categoria_pertencente == lista_probcats[0]:
        return 0
    if categoria_pertencente == lista_probcats[1]:
        return 1
    if categoria_pertencente == lista_probcats[2]:
        return 2
    if categoria_pertencente == lista_probcats[3]:
        return 3

# %%
test["classificador"] = test.Teste.apply(classificador)
test.tail(50)
# Out:
#                                                  Teste  Classificação  \
# 300        do do do do do           https//tco/3b1z...              0
# 301        do do do do do           babydoge babydo...              0
# 302      do do do do do           babydoge babydoge...              0
# 303      do do do do do           babydoge babydoge...              0
# 304        do do do do do           https//tco/gbi8...              0
# 305  malditos templários acabaram com a história do...              0
# 306   einstein e tesla mas acho q o tesla recusaria...              0
# 307       tesla já era rico e bem sucedido antes de...              0
# 308        do do do do do           babydoge babydo...              0
# 309      do do do do do           babydoge babydoge...              0
# 310  https//tco/uxvplrdior\n\nbaita comparativo int...              2
# 311  tesla terá que dividir dados de sistema de dir...              1
# 312    se bem que o tesla n eh mt diferente do eins...              0
# 313      do do do do do           babydoge babydoge...              0
# 314   hawking por ser o mais recente e newton por s...              0
# 315      do do do do do           babydoge babydoge...              0
# 316        do do do do do           babydoge babydo...              0
# 317                           newton e tesla n sei kkk              0
# 318      do do do do do           babydoge babydoge...              0
# 319  como eu amo essa referencia ao nikola tesla no...              0
# 320               tesla e einsten dariam uma boa ajuda              0
# 321        do do do do do           babydoge babydo...              0
# 322      do do do do do           babydoge babydoge...              0
# 323  fui no aniversário da minha prima e o padrinho...              0
# 324   como eu sou burro e o einstein já repetiu mt ...              0
# 325  homem fez o “golpe do atropelamento” mas tesla...              0
# 326   eu ia pedir a ajuda de tesla só pq eu n quero...              0
# 327  ai agnt pegou tbm a bborges a jullya e o kauã ...              1
# 328      do do do do do           babydoge babydoge...              0
# 329   e hoje o filho dele é o bilionario dono da te...              1
# 330   pior que o plano do tesla era usar eletricida...              0
# 331  https//tco/o6pjjvbof5\n\nfoi essa mesma pergun...              2
# 332  sonhei com um tesla hj senhor se for sua vonta...              1
# 333      do do do do do           babydoge babydoge...              0
# 334                                    cade meu tesla               1
# 335    tesla é um dos maiores físicos da história m...              0
# 336        do do do do do           https//tco/a6fu...              0
# 337                                     tesla brabo né              1
# 338   será que o sw é realmente outro\n\nserá que n...              1
# 339        do do do do do           babydoge babydo...              0
# 340         um gajo num tesla a tirar macacos do nariz              1
# 341    eu conto ou voces são a notícia\n😁😁😁😁😁😁\n\nl...              0
# 342  se você quiser descobrir os segredos do univer...              0
# 343  hawking e tesla e o resto faz as questão\n\nfi...              0
# 344          esse sinal do tesla demora pra bater hein              0
# 345        do do do do do           babydoge babydo...              0
# 346        do do do do do           https//tco/ej9p...              0
# 347        do do do do do           https//tco/htom...              0
# 348    diz aí como que um ladrão deixa 380bilhões d...              0
# 349        gracias emilio disparo único ƒ/28 15s is...              0
#
#      Classificador  classificador
# 300            NaN              3
# 301            NaN              3
# 302            NaN              3
# 303            NaN              3
# 304            NaN              3
# 305            NaN              3
# 306            NaN              3
# 307            NaN              3
# 308            NaN              3
# 309            NaN              3
# 310            NaN              2
# 311            NaN              1
# 312            NaN              3
# 313            NaN              3
# 314            NaN              3
# 315            NaN              3
# 316            NaN              3
# 317            NaN              3
# 318            NaN              3
# 319            NaN              3
# 320            NaN              3
# 321            NaN              3
# 322            NaN              3
# 323            NaN              3
# 324            NaN              3
# 325            NaN              3
# 326            NaN              3
# 327            NaN              3
# 328            NaN              3
# 329            NaN              3
# 330            NaN              3
# 331            NaN              3
# 332            NaN              3
# 333            NaN              3
# 334            NaN              2
# 335            NaN              3
# 336            NaN              3
# 337            NaN              2
# 338            NaN              2
# 339            NaN              3
# 340            NaN              3
# 341            NaN              3
# 342            NaN              3
# 343            NaN              3
# 344            NaN              2
# 345            NaN              3
# 346            NaN              3
# 347            NaN              3
# 348            NaN              3
# 349            NaN              1

# %%
def p(n):
    x = 0
    y = 0
    if p == test.classificador:
        x+=1
        y+=1
    else:
        y+=1
    return (x/y)*100

test.Classificação.apply(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-226-cb8a18330fbd> in <module>
#       9     return (x/y)*100
#      10
# ---> 11 test.Classificação.apply(p)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-226-cb8a18330fbd> in p(n)
#       2     x = 0
#       3     y = 0
# ----> 4     if p == test.classificador:
#       5         x+=1
#       6         y+=1
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
#test.Teste.apply(classificador1)

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# ___
# ### Qualidade do Classificador a partir de novas separações dos tweets entre Treinamento e Teste
#
# Caso for fazer esse item do Projeto

# %% [markdown]
# ___
# ## Aperfeiçoamento:
#
# Trabalhos que conseguirem pelo menos conceito B vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * IMPLEMENTOU outras limpezas e transformações que não afetem a qualidade da informação contida nos tweets. Ex: stemming, lemmatization, stopwords
# * CORRIGIU separação de espaços entre palavras e emojis ou entre emojis e emojis
# * CRIOU categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante. Pelo menos quatro categorias, com adição de mais tweets na base, conforme enunciado. (OBRIGATÓRIO PARA TRIOS, sem contar como item avançado)
# * EXPLICOU porquê não pode usar o próprio classificador para gerar mais amostras de treinamento
# * PROPÔS diferentes cenários para Naïve Bayes fora do contexto do projeto
# * SUGERIU e EXPLICOU melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)
# * FEZ o item 6. Qualidade do Classificador a partir de novas separações dos tweets entre Treinamento e Teste descrito no enunciado do projeto (OBRIGATÓRIO para conceitos A ou A+)

# %% [markdown]
# ___
# ## Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**

# %% [markdown]
# ##
